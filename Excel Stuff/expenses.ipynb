# %%
# a program that writes to an excel spreadsheet

import openpyxl
from openpyxl.utils import get_column_letter, column_index_from_string

wb = openpyxl.load_workbook('expenses.xlsx')
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
wb.get_sheet_names()
sheet = wb.get_sheet_by_name('Sheet3')
sheet
# Out:
# C:\Users\rking\AppData\Local\Temp\ipykernel_26088\3566334551.py:1: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   wb.get_sheet_names()
# C:\Users\rking\AppData\Local\Temp\ipykernel_26088\3566334551.py:2: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   sheet = wb.get_sheet_by_name('Sheet3')
# <Worksheet "Sheet3">

# %%
anotherSheet = wb.active
anotherSheet
# Out:
# <Worksheet "Sheet1">

# %%
sheet = wb.get_sheet_by_name('Sheet1')
sheet['A1']

c = sheet['B1']
c.value
#'Row ' + str(c.row) + ', Column ' + c.column + ' is ' + c.value
# Out:
# C:\Users\rking\AppData\Local\Temp\ipykernel_26088\3088896366.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   sheet = wb.get_sheet_by_name('Sheet1')
# 'Apples'

# %%
'Row ', c.row, ', Column ', c.column, ' is ', c.value

'Cell ' + c.coordinate + ' is ' + c.value
# Out:
# Row  1 , Column  2  is  Apples

# %%
for i in range(1, 8, 2):
        print(i, sheet.cell(row=i, column=2).value)
# Out:
# 1 Apples
# 3 Pears
# 5 Apples
# 7 Strawberries

# %%
get_column_letter(27)
# Out:
# 'AA'

# %%
column_index_from_string('AA')
# Out:
# 27

# %%
for rowOfCellObjects in sheet['A1':'C3']:
        for cellObj in rowOfCellObjects:
            print(cellObj.coordinate, cellObj.value)
            print('--- END OF ROW ---')
# Out:
# A1 2015-04-05 13:34:02
# --- END OF ROW ---
# B1 Apples
# --- END OF ROW ---
# C1 73
# --- END OF ROW ---
# A2 2015-04-05 03:41:23
# --- END OF ROW ---
# B2 Cherries
# --- END OF ROW ---
# C2 85
# --- END OF ROW ---
# A3 2015-04-06 12:46:51
# --- END OF ROW ---
# B3 Pears
# --- END OF ROW ---
# C3 14
# --- END OF ROW ---

# %%
wb = openpyxl.load_workbook('expenses.xlsx')
sheet = wb.active
sheet['B']

for cellObj in sheet['B']:
        print(cellObj.value)
# Out:
# Apples
# Cherries
# Pears
# Oranges
# Apples
# Bananas
# Strawberries
